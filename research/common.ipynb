# %%
# %pwd
# Out:
# 'c:\\Users\\Dhanush Ramachandran\\Desktop\\Dhanush --\\Personal DS\\MLops\\end-to-end project\\project'

# %%
import os
os.chdir("../")

# %%
from ensure import ensure_annotations

@ensure_annotations  # makes the data type matching to be strict
def get_product(x:int,y:int) -> int:
    return x*y
print(get_product(2,"3"))
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[6], line 7
#       3 @ensure_annotations
#       4 def get_product(x:int,y:int) -> int:
#       5     return x*y
# ----> 7 print(get_product(2,"3"))
#
# File c:\Users\Dhanush Ramachandran\Desktop\Dhanush --\Personal DS\MLops\end-to-end project\project\venv\Lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# ...
